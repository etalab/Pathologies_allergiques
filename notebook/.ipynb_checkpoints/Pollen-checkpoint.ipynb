# %% [markdown]
# Données : http://www.data.gouv.fr/fr/datasets/indicateur-avance-sanitaire-ias-r-manifestations-allergiques/
#
# L’IAS® Allergies permet désormais d’analyser le **niveau des pathologies allergiques en France au jour le jour**. Il est particulièrement adapté au suivi de l’évolution spatio-temporelle des allergies saisonnières. Du cyprès à partir de février jusqu’à l’ambroisie en août, vous pourrez visualiser l’évolution des pathologies allergiques à J+1 et tout au long de l’année. Cet IAS® se positionne comme complémentaire de la surveillance des pollens par le Réseau National de Surveillance Aérobiologique, qui est un système de suivi des facteurs de risques.
#
# Le modèle utilisé pour l’IAS® Allergies est **basé sur le suivi d’un ensemble de médicaments indiqués dans le traitement symptomatique des allergies** de la France et utilise les méthodes d’analyse et de représentations développées par le projet
#
# Auteur: Florian Gauthier

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib import gridspec

# %matplotlib inline

# %%
allergies = pd.read_csv('../data/Openhealth_allergies.csv', sep=';', encoding='latin-1')

# %%
allergies_regions = pd.read_csv('../data/Openhealth_allergies_Regions.csv', sep=';')

# %%
allergies_regions.head(2).transpose()
# Out:
#                          0           1
# PERIODE         01-10-2016  02-10-2016
# Senti                  NaN         NaN
# Sais_2015_2016        97,4        97,2
# Sais_2014_2015        97,6        97,4
# Sais_2013_2014        97,1          97
# Sais_2012_2013        96,8        96,6
# Sais_2011_2012        99,6        98,9
# Sais_2010_2011        92,7        92,3
# Sais_2009_2010         NaN         NaN
# Sais_2008_2009         NaN         NaN
# Loc_Reg11           101,18      101,04
# Loc_Reg21           98,185       97,88
# Loc_Reg22            99,18       99,39
# Loc_Reg23          101,375       100,8
# Loc_Reg24            97,47       97,12
# Loc_Reg25            95,28       95,18
# Loc_Reg26            98,82       97,78
# Loc_Reg31           99,275       98,61
# Loc_Reg41           96,835      96,205
# Loc_Reg42           96,425       95,79
# Loc_Reg43           98,765       97,79
# Loc_Reg52            94,56       94,08
# Loc_Reg53           97,325       97,02
# Loc_Reg54           97,175      97,035
# Loc_Reg72           100,39       99,93
# Loc_Reg73           102,88      102,51
# Loc_Reg74           101,87      101,46
# Loc_Reg82           103,65      103,22
# Loc_Reg83           100,44      100,07
# Loc_Reg91            99,67      99,605
# Loc_Reg93            96,29       96,64
# Loc_Reg94           100,78     100,275
# MIN_Saison            92,7        92,3
# MAX_Saison            99,6        98,9
# IN_Def                99,2        98,7
# IN_Temp                NaN         NaN

# %%
allergies_regions
# Out:
#         PERIODE  Senti Sais_2015_2016 Sais_2014_2015 Sais_2013_2014  \
# 0    01-10-2016    NaN           97,4           97,6           97,1
# 1    02-10-2016    NaN           97,2           97,4             97
# 2    03-10-2016    NaN           96,9           97,2           96,8
# 3    04-10-2016    NaN           96,5           96,8           96,2
# 4    05-10-2016    NaN           96,2           96,4           95,5
# 5    06-10-2016    NaN             96           96,1           94,8
# 6    07-10-2016    NaN           95,7           95,8           94,2
# 7    08-10-2016    NaN           95,2           95,5           93,7
# 8    09-10-2016    NaN           94,6           95,3           93,4
# 9    10-10-2016    NaN             94           94,9           93,1
# 10   11-10-2016    NaN           93,4           94,3           92,9
# 11   12-10-2016    NaN           92,9           93,8           92,6
# 12   13-10-2016    NaN           92,7           93,4           92,4
# 13   14-10-2016    NaN           92,5           93,2           92,4
# 14   15-10-2016    NaN           92,5           93,2           92,4
# 15   16-10-2016    NaN           92,5           93,2           92,5
# 16   17-10-2016    NaN           92,5           93,2           92,6
# 17   18-10-2016    NaN           92,4           93,2           92,8
# 18   19-10-2016    NaN           92,4           93,3             93
# 19   20-10-2016    NaN           92,3           93,6           93,2
# 20   21-10-2016    NaN           92,2             94           93,4
# 21   22-10-2016    NaN           91,8           94,3           93,6
# 22   23-10-2016    NaN           91,3           94,4           93,6
# 23   24-10-2016    NaN           90,6           94,3           93,6
# 24   25-10-2016    NaN           89,9             94           93,4
# 25   26-10-2016    NaN           89,3           93,7           93,2
# 26   27-10-2016    NaN           88,7           93,5             93
# 27   28-10-2016    NaN           88,2           93,3           92,9
# 28   29-10-2016    NaN           87,7             93           92,9
# 29   30-10-2016    NaN           87,1           92,5           92,8
# ..          ...    ...            ...            ...            ...
# 336  02-09-2017    NaN            103             98          100,4
# 337  03-09-2017    NaN          102,1           97,7          100,3
# 338  04-09-2017    NaN          101,4           97,5          100,1
# 339  05-09-2017    NaN          100,7           97,4            100
# 340  06-09-2017    NaN          100,4           97,5           99,9
# 341  07-09-2017    NaN          100,4           97,9            100
# 342  08-09-2017    NaN          100,4           98,3          100,2
# 343  09-09-2017    NaN          100,8           98,8          100,7
# 344  10-09-2017    NaN          101,2             99          101,1
# 345  11-09-2017    NaN          101,5           99,2          101,5
# 346  12-09-2017    NaN          101,7           99,2            102
# 347  13-09-2017    NaN          101,8           99,2          102,2
# 348  14-09-2017    NaN          101,7           99,3          102,4
# 349  15-09-2017    NaN          101,4           99,4          102,5
# 350  16-09-2017    NaN            101           99,5          102,4
# 351  17-09-2017    NaN          100,7           99,6          102,2
# 352  18-09-2017    NaN          100,6           99,6          101,9
# 353  19-09-2017    NaN          100,8           99,7          101,4
# 354  20-09-2017    NaN          101,1           99,7            101
# 355  21-09-2017    NaN          101,5           99,7          100,5
# 356  22-09-2017    NaN          101,8           99,8          100,2
# 357  23-09-2017    NaN          101,8           99,8            100
# 358  24-09-2017    NaN          101,6           99,5           99,8
# 359  25-09-2017    NaN          101,3           99,2           99,6
# 360  26-09-2017    NaN            101           98,7           99,3
# 361  27-09-2017    NaN          100,7           98,3           98,9
# 362  28-09-2017    NaN          100,3             98           98,5
# 363  29-09-2017    NaN            100           97,8           98,1
# 364  30-09-2017    NaN           99,7           97,6           97,8
# 365               NaN            NaN            NaN            NaN
#
#     Sais_2012_2013 Sais_2011_2012 Sais_2010_2011 Sais_2009_2010  \
# 0             96,8           99,6           92,7            NaN
# 1             96,6           98,9           92,3            NaN
# 2             96,7           98,3           91,9            NaN
# 3             96,9             98           91,6            NaN
# 4             96,9           97,7           91,5            NaN
# 5             96,8           97,3           91,5            NaN
# 6             96,7           96,7           91,5            NaN
# 7             96,7             96           91,5            NaN
# 8             96,7           95,4           91,6            NaN
# 9             96,9             95           91,7            NaN
# 10            97,1           94,9           91,8            NaN
# 11            97,2             95             92            NaN
# 12            97,2           95,3           92,2            NaN
# 13            97,1           95,6           92,2            NaN
# 14            97,1           95,8             92            NaN
# 15            97,1             96           91,6            NaN
# 16              97           96,2           91,2            NaN
# 17            96,8           96,3             91            NaN
# 18            96,5           96,5             91            NaN
# 19            96,2           96,7           91,1            NaN
# 20              96           96,8           91,1            NaN
# 21            95,8           96,9           90,9            NaN
# 22            95,7           96,9           90,8            NaN
# 23            95,9             97           90,8            NaN
# 24            96,2           97,2           90,8            NaN
# 25            96,5           97,4             91            NaN
# 26            96,9           97,6             91            NaN
# 27            97,5           97,5             91            NaN
# 28              98             97           90,6            NaN
# 29            98,5           96,4             90            NaN
# ..             ...            ...            ...            ...
# 336           99,3           98,5           95,3           94,5
# 337           99,2           98,3           94,7           94,2
# 338           98,9           98,2             94           93,9
# 339           98,5           98,2           93,6           93,4
# 340           98,1           98,3           93,5             93
# 341           97,6           98,3           93,6           92,8
# 342           97,3           98,3           93,7           92,9
# 343           97,1           98,4             94           93,3
# 344           97,1           98,7           94,3           93,8
# 345           97,3           99,1             95           94,4
# 346           97,5           99,5           95,7             95
# 347           97,9            100           96,5           95,8
# 348           98,2          100,5           97,2           96,5
# 349           98,7            101             98           97,3
# 350           99,1          101,5           98,8           97,8
# 351           99,5          102,1           99,4             98
# 352            100          102,6            100           98,3
# 353          100,4            103          100,7           98,5
# 354          100,8          103,1          101,4           98,6
# 355            101          102,9            102           98,7
# 356            101          102,2          102,5           98,5
# 357            101          101,5          102,7             98
# 358          100,8          100,7          102,7           97,3
# 359          100,5            100          102,4           96,1
# 360           99,9           99,3          102,1             95
# 361           99,2           98,7          101,7           94,2
# 362           98,5           98,1          101,3           93,6
# 363           97,9           97,5          100,9           93,2
# 364           97,4             97          100,3           92,9
# 365            NaN            NaN            NaN            NaN
#
#      Sais_2008_2009   ...   Loc_Reg74 Loc_Reg82 Loc_Reg83 Loc_Reg91 Loc_Reg93  \
# 0               NaN   ...      101,87    103,65    100,44     99,67     96,29
# 1               NaN   ...      101,46    103,22    100,07    99,605     96,64
# 2               NaN   ...      101,22   102,695     99,65    99,345     97,15
# 3               NaN   ...      101,11    101,98     99,28     99,01      97,5
# 4               NaN   ...      100,97    101,33     98,91    98,525     97,51
# 5               NaN   ...      100,78    100,45     98,39     97,96     97,18
# 6               NaN   ...      100,64     99,41     97,78    97,015     96,74
# 7               NaN   ...      100,45     98,51     97,19    95,965     96,18
# 8               NaN   ...      100,15    97,745     96,78    94,935     95,66
# 9               NaN   ...       99,78     97,32     96,56    94,045     95,42
# 10              NaN   ...       99,39     97,17     96,51     93,71     95,07
# 11              NaN   ...       98,92    97,285     96,57    93,645     94,86
# 12              NaN   ...        98,4      97,4     96,43      93,6     94,78
# 13              NaN   ...       97,74      97,3     96,29    93,735     94,71
# 14              NaN   ...       97,15    97,295     96,28    93,895     94,79
# 15              NaN   ...       96,61    97,375     96,44     93,93     94,73
# 16              NaN   ...       96,23    97,585     96,66     93,88     94,84
# 17              NaN   ...       96,22    97,895     96,74     93,84      94,9
# 18              NaN   ...       96,39    98,325     96,95    93,885     95,14
# 19              NaN   ...        96,8    98,575     97,21    93,995     95,48
# 20              NaN   ...       97,17    98,635     97,31    93,885        96
# 21              NaN   ...       97,42     98,43      97,3    93,705     96,14
# 22              NaN   ...       97,74     98,14     97,18    93,285     95,96
# 23              NaN   ...       98,17    97,825     97,01     92,82      95,6
# 24              NaN   ...       98,69     97,42     96,82     92,51     95,11
# 25              NaN   ...       99,06    96,885     96,56    92,315     94,58
# 26              NaN   ...       99,34      96,3     96,33    92,055     94,03
# 27              NaN   ...       99,39    95,755     96,18     91,84     93,48
# 28              NaN   ...       99,24    95,145     95,88    91,645     93,02
# 29              NaN   ...       98,76     94,56     95,67     91,59     92,68
# ..              ...   ...         ...       ...       ...       ...       ...
# 336             NaN   ...         NaN       NaN       NaN       NaN       NaN
# 337             NaN   ...         NaN       NaN       NaN       NaN       NaN
# 338             NaN   ...         NaN       NaN       NaN       NaN       NaN
# 339             NaN   ...         NaN       NaN       NaN       NaN       NaN
# 340             NaN   ...         NaN       NaN       NaN       NaN       NaN
# 341             NaN   ...         NaN       NaN       NaN       NaN       NaN
# 342             NaN   ...         NaN       NaN       NaN       NaN       NaN
# 343             NaN   ...         NaN       NaN       NaN       NaN       NaN
# 344             NaN   ...         NaN       NaN       NaN       NaN       NaN
# 345             NaN   ...         NaN       NaN       NaN       NaN       NaN
# 346             NaN   ...         NaN       NaN       NaN       NaN       NaN
# 347             NaN   ...         NaN       NaN       NaN       NaN       NaN
# 348             NaN   ...         NaN       NaN       NaN       NaN       NaN
# 349             NaN   ...         NaN       NaN       NaN       NaN       NaN
# 350             NaN   ...         NaN       NaN       NaN       NaN       NaN
# 351             NaN   ...         NaN       NaN       NaN       NaN       NaN
# 352             NaN   ...         NaN       NaN       NaN       NaN       NaN
# 353             NaN   ...         NaN       NaN       NaN       NaN       NaN
# 354             NaN   ...         NaN       NaN       NaN       NaN       NaN
# 355             NaN   ...         NaN       NaN       NaN       NaN       NaN
# 356             NaN   ...         NaN       NaN       NaN       NaN       NaN
# 357             NaN   ...         NaN       NaN       NaN       NaN       NaN
# 358             NaN   ...         NaN       NaN       NaN       NaN       NaN
# 359             NaN   ...         NaN       NaN       NaN       NaN       NaN
# 360             NaN   ...         NaN       NaN       NaN       NaN       NaN
# 361             NaN   ...         NaN       NaN       NaN       NaN       NaN
# 362             NaN   ...         NaN       NaN       NaN       NaN       NaN
# 363             NaN   ...         NaN       NaN       NaN       NaN       NaN
# 364             NaN   ...         NaN       NaN       NaN       NaN       NaN
# 365             NaN   ...         NaN       NaN       NaN       NaN       NaN
#
#     Loc_Reg94 MIN_Saison MAX_Saison IN_Def IN_Temp
# 0      100,78       92,7       99,6   99,2     NaN
# 1     100,275       92,3       98,9   98,7     NaN
# 2       99,13       91,9       98,3   98,5     NaN
# 3      97,655       91,6         98   98,4     NaN
# 4       96,11       91,5       97,7   98,2     NaN
# 5       94,57       91,5       97,3   97,9     NaN
# 6        93,1       91,5       96,7   97,5     NaN
# 7      91,825       91,5       96,7     97     NaN
# 8      90,635       91,6       96,7   96,7     NaN
# 9      89,565       91,7       96,9   96,5     NaN
# 10      88,78       91,8       97,1   96,4     NaN
# 11     88,335         92       97,2   96,4     NaN
# 12       88,6       92,2       97,2   96,4     NaN
# 13      89,31       92,2       97,1   96,2     NaN
# 14      90,13         92       97,1   96,2     NaN
# 15     90,975       91,6       97,1   96,2     NaN
# 16      92,18       91,2         97   96,3     NaN
# 17      93,48         91       96,8   96,5     NaN
# 18      94,67         91       96,5   96,7     NaN
# 19      95,57       91,1       96,7   96,9     NaN
# 20     96,185       91,1       96,8     97     NaN
# 21      96,24       90,9       96,9   97,1     NaN
# 22     96,355       90,8       96,9   97,1     NaN
# 23     97,045       90,6         97   97,1     NaN
# 24     97,795       89,9       97,2     97     NaN
# 25     98,295       89,3       97,4   96,9     NaN
# 26      98,45       88,7       97,6   96,8     NaN
# 27     98,245       88,2       97,5   96,6     NaN
# 28     98,015       87,7         98   96,4     NaN
# 29     98,085       87,1       98,5   96,3     NaN
# ..        ...        ...        ...    ...     ...
# 336       NaN       94,5        103    NaN     NaN
# 337       NaN       94,2      102,1    NaN     NaN
# 338       NaN       93,9      101,4    NaN     NaN
# 339       NaN       93,4      100,7    NaN     NaN
# 340       NaN         93      100,4    NaN     NaN
# 341       NaN       92,8      100,4    NaN     NaN
# 342       NaN       92,9      100,4    NaN     NaN
# 343       NaN       93,3      100,8    NaN     NaN
# 344       NaN       93,8      101,2    NaN     NaN
# 345       NaN       94,4      101,5    NaN     NaN
# 346       NaN         95        102    NaN     NaN
# 347       NaN       95,8      102,2    NaN     NaN
# 348       NaN       96,5      102,4    NaN     NaN
# 349       NaN       97,3      102,5    NaN     NaN
# 350       NaN       97,8      102,4    NaN     NaN
# 351       NaN         98      102,2    NaN     NaN
# 352       NaN       98,3      102,6    NaN     NaN
# 353       NaN       98,5        103    NaN     NaN
# 354       NaN       98,6      103,1    NaN     NaN
# 355       NaN       98,7      102,9    NaN     NaN
# 356       NaN       98,5      102,5    NaN     NaN
# 357       NaN         98      102,7    NaN     NaN
# 358       NaN       97,3      102,7    NaN     NaN
# 359       NaN       96,1      102,4    NaN     NaN
# 360       NaN         95      102,1    NaN     NaN
# 361       NaN       94,2      101,7    NaN     NaN
# 362       NaN       93,6      101,3    NaN     NaN
# 363       NaN       93,2      100,9    NaN     NaN
# 364       NaN       92,9      100,3    NaN     NaN
# 365       NaN        NaN        NaN    NaN     NaN
#
# [366 rows x 36 columns]

# %%
allergies_regions.PERIODE = pd.to_datetime(allergies_regions.PERIODE, dayfirst=True, errors='coerce')
allergies_regions.dropna(subset=['PERIODE'], inplace=True)

# %%
(allergies_regions.isnull().sum() / len(allergies_regions)).sort_values(ascending=False).plot(
    kind='bar',
    figsize=(10,3),
    title='Données manquantes (%)')

# %%
allergies_regions.shape
# Out:
# (365, 36)

# %% [markdown]
# ## Nettoyage de la table

# %%
# Conversion au format date
allergies_regions.PERIODE = pd.to_datetime(allergies_regions.PERIODE, dayfirst=True, errors='coerce')
allergies_regions.dropna(subset=['PERIODE'], inplace=True)
# On remplace les ',' par des '.'
allergies_regions = allergies_regions.applymap(lambda x: x.replace(',', '.') if isinstance(x, str) else x)
# Conversion en numérique
for col in allergies_regions.columns:
    if col != 'PERIODE':
        allergies_regions[col] = pd.to_numeric(allergies_regions[col], errors='ignore')

# %%
# On met la période en index
allergies_regions.set_index('PERIODE', inplace=True)

# %%
sais_col = [x for x in allergies_regions.columns if x.startswith('Sais_') ]
reg_col = [x for x in allergies_regions.columns if x.startswith('Loc_') ]

# %%
allergies_regions.index.min()
# Out:
# Timestamp('2016-10-01 00:00:00')

# %% [markdown]
# ### On récupère le nom des régions (ref=2015)

# %%
region_ref_2015 = pd.read_csv('../data/reg2015.txt', sep="\t", encoding='latin-1')
region_ref_2015.REGION = region_ref_2015.REGION.astype(str)
region_ref_2015.head(2)
# Out:
#   REGION CHEFLIEU  TNCC         NCC      NCCENR
# 0      1    97105     3  GUADELOUPE  Guadeloupe
# 1      2    97209     3  MARTINIQUE  Martinique

# %%
regions_dict_2015 = region_ref_2015.set_index('REGION')['NCC'].to_dict()
reg_col_new = [regions_dict_2015[x[1]] for x in allergies_regions[reg_col].columns.str.split('Reg')]
reg_col_dict = dict(zip(reg_col, reg_col_new))
# On recomme les colonnes code_région par leur noms.
allergies_regions.rename(columns=reg_col_dict, inplace=True)

# %%
allergies_regions.head(2)
# Out:
#             Senti  Sais_2015_2016  Sais_2014_2015  Sais_2013_2014  \
# PERIODE
# 2016-10-01    NaN            97.4            97.6            97.1
# 2016-10-02    NaN            97.2            97.4            97.0
#
#             Sais_2012_2013  Sais_2011_2012  Sais_2010_2011  Sais_2009_2010  \
# PERIODE
# 2016-10-01            96.8            99.6            92.7             NaN
# 2016-10-02            96.6            98.9            92.3             NaN
#
#             Sais_2008_2009  ILE-DE-FRANCE   ...     LIMOUSIN  RHONE-ALPES  \
# PERIODE                                     ...
# 2016-10-01             NaN         101.18   ...       101.87       103.65
# 2016-10-02             NaN         101.04   ...       101.46       103.22
#
#             AUVERGNE  LANGUEDOC-ROUSSILLON  PROVENCE-ALPES-COTE D'AZUR  \
# PERIODE
# 2016-10-01    100.44                99.670                       96.29
# 2016-10-02    100.07                99.605                       96.64
#
#               CORSE  MIN_Saison  MAX_Saison  IN_Def  IN_Temp
# PERIODE
# 2016-10-01  100.780        92.7        99.6    99.2      NaN
# 2016-10-02  100.275        92.3        98.9    98.7      NaN
#
# [2 rows x 35 columns]

# %% [markdown]
# ## Evolution des pathologie allergiques en France et par région

# %%
allergies_regions[reg_col_new].plot(figsize=(17, 10), title='Pathologies allergiques en France par région\n(Source: Open Health)')

# %% [markdown]
# On observer un énorme pic de pathologies allergiques entre les mois de Février et Avril 2017 en région PACA.

# %%
allergies_regions[sais_col].plot(figsize=(17, 10))

# %% [markdown]
# # Episodes de polution
#
# Données de dépassements de seuils par polluant et par région.
#
# http://www.lcsqa.org/indices-qualite-air/liste

# %%
episodes_pollution = pd.read_csv('../data/episodes_pollution.csv', sep=';')

# %%
episodes_pollution.head(4)
# Out:
#   Date de l'épisode  Origine Polluant    Région      Département  \
# 0        01/01/2017  CONSTAT      NO2  BRETAGNE        FINISTERE
# 1        01/01/2017  CONSTAT     PM10  BRETAGNE        FINISTERE
# 2        04/01/2017  CONSTAT     PM10  BRETAGNE  ILLE-ET-VILAINE
# 3        04/01/2017  CONSTAT     PM10    GUYANE           GUYANE
#
#     Seuil dépassé
# 0  200 µg/m³ / 1h
# 1  50 µg/m³ / 24h
# 2  50 µg/m³ / 24h
# 3  80 µg/m³ / 24h

# %%
episodes_pollution.Polluant.value_counts() / len(episodes_pollution)
# Out:
# PM10    0.877850
# O3      0.060261
# NO2     0.035831
# SO2     0.026059
# Name: Polluant, dtype: float64

# %%
episodes_pollution['Seuil dépassé'].value_counts()
# Out:
# 50 µg/m³ / 24h    427
# 80 µg/m³ / 24h    105
# 180 µg/m³ / 1h     36
# 200 µg/m³ / 1h     22
# 300 µg/m³ / 1h     16
# Name: Seuil dépassé, dtype: int64

# %% [markdown]
# ### Nettoyage de la table

# %%
episodes_pollution['Date de l\'épisode'] = pd.to_datetime(episodes_pollution['Date de l\'épisode'])
#episodes_pollution.set_index('Date de l\'épisode', inplace=True)

# %%
episodes_pollution['Seuil dépassé'] = [int(x.split(' µ')[0]) if isinstance(x, str) else x for x in episodes_pollution['Seuil dépassé']]

# %%
episodes_pollution.dropna(inplace=True)

# %% [markdown]
# ### Création de la table : date x dépassement / polluant / région

# %%
polluant_by_regions = episodes_pollution.groupby('Région')['Date de l\'épisode', 'Seuil dépassé', 'Polluant'].apply(lambda x: x.to_dict('split')['data'])

# %%
polluant_by_regions.head()
# Out:
# Région
# ALSACE             [[2017-01-20 00:00:00, 50.0, PM10], [2017-01-2...
# AQUITAINE          [[2017-05-01 00:00:00, 50.0, PM10], [2016-10-1...
# AUVERGNE           [[2016-12-16 00:00:00, 50.0, PM10], [2016-12-1...
# BASSE-NORMANDIE    [[2016-12-27 00:00:00, 50.0, PM10], [2016-02-1...
# BOURGOGNE          [[2016-10-12 00:00:00, 50.0, PM10], [2016-12-1...
# dtype: object

# %%
date_index = pd.DataFrame(pd.date_range('2016-01', '2017-06-01'), columns=['date'])
date_index.head()
# Out:
#         date
# 0 2016-01-01
# 1 2016-01-02
# 2 2016-01-03
# 3 2016-01-04
# 4 2016-01-05

# %%
final_table = pd.DataFrame(pd.date_range('2016-10-01', '2017-06-01'), columns=['date'])
for pol in episodes_pollution.Polluant.unique():
    polluant_spe = episodes_pollution[episodes_pollution.Polluant == pol]
    polluant_by_regions = polluant_spe.groupby('Région')['Date de l\'épisode', 'Seuil dépassé'].apply(lambda x: x.to_dict('split')['data'])
    for region in polluant_by_regions.keys():
        region_df = pd.DataFrame(polluant_by_regions[region], columns=['date', region+'_'+pol])
        final_table = pd.merge(final_table, region_df, on='date', how='left').drop_duplicates(subset=['date', region+'_'+pol])

# %%
final_table.set_index('date', inplace=True)

# %%
final_table.head(2)
# Out:
#             BRETAGNE_NO2  ILE-DE-FRANCE_NO2  RHONE-ALPES_NO2  ALSACE_PM10  \
# date
# 2016-10-01           NaN                NaN              NaN          NaN
# 2016-10-02           NaN                NaN              NaN          NaN
#
#             AQUITAINE_PM10  AUVERGNE_PM10  BASSE-NORMANDIE_PM10  \
# date
# 2016-10-01             NaN            NaN                   NaN
# 2016-10-02             NaN            NaN                   NaN
#
#             BOURGOGNE_PM10  BRETAGNE_PM10  CENTRE_PM10       ...         \
# date                                                         ...
# 2016-10-01             NaN            NaN          NaN       ...
# 2016-10-02             NaN            NaN          NaN       ...
#
#             MIDI-PYRENEES_O3  NORD-PAS-DE-CALAIS_O3  RHONE-ALPES_O3  \
# date
# 2016-10-01               NaN                    NaN             NaN
# 2016-10-02               NaN                    NaN             NaN
#
#             AQUITAINE_SO2  HAUTE-NORMANDIE_SO2  LA REUNION_SO2  \
# date
# 2016-10-01            NaN                  NaN             NaN
# 2016-10-02            NaN                  NaN             NaN
#
#             NORD-PAS-DE-CALAIS_SO2  PAYS DE LA LOIRE_SO2  \
# date
# 2016-10-01                     NaN                   NaN
# 2016-10-02                     NaN                   NaN
#
#             PROVENCE-ALPES-COTE D'AZUR_SO2  RHONE-ALPES_SO2
# date
# 2016-10-01                             NaN              NaN
# 2016-10-02                             NaN              NaN
#
# [2 rows x 43 columns]

# %%
# Liste des régions disponibles dans la table (les 26)
all_polluants_regions = set([col.split('_')[0] for col in final_table.columns.unique()])

# %% [markdown]
# # PLOT ALL REGIONS

# %%
allergies_regions.head(2)
# Out:
#             Senti  Sais_2015_2016  Sais_2014_2015  Sais_2013_2014  \
# PERIODE
# 2016-10-01    NaN            97.4            97.6            97.1
# 2016-10-02    NaN            97.2            97.4            97.0
#
#             Sais_2012_2013  Sais_2011_2012  Sais_2010_2011  Sais_2009_2010  \
# PERIODE
# 2016-10-01            96.8            99.6            92.7             NaN
# 2016-10-02            96.6            98.9            92.3             NaN
#
#             Sais_2008_2009  ILE-DE-FRANCE   ...     LIMOUSIN  RHONE-ALPES  \
# PERIODE                                     ...
# 2016-10-01             NaN         101.18   ...       101.87       103.65
# 2016-10-02             NaN         101.04   ...       101.46       103.22
#
#             AUVERGNE  LANGUEDOC-ROUSSILLON  PROVENCE-ALPES-COTE D'AZUR  \
# PERIODE
# 2016-10-01    100.44                99.670                       96.29
# 2016-10-02    100.07                99.605                       96.64
#
#               CORSE  MIN_Saison  MAX_Saison  IN_Def  IN_Temp
# PERIODE
# 2016-10-01  100.780        92.7        99.6    99.2      NaN
# 2016-10-02  100.275        92.3        98.9    98.7      NaN
#
# [2 rows x 35 columns]

# %%
final_table.columns
# Out:
# Index(['BRETAGNE_NO2', 'ILE-DE-FRANCE_NO2', 'RHONE-ALPES_NO2', 'ALSACE_PM10',
#        'AQUITAINE_PM10', 'AUVERGNE_PM10', 'BASSE-NORMANDIE_PM10',
#        'BOURGOGNE_PM10', 'BRETAGNE_PM10', 'CENTRE_PM10',
#        'CHAMPAGNE-ARDENNE_PM10', 'CORSE_PM10', 'FRANCHE-COMTE_PM10',
#        'GUADELOUPE_PM10', 'GUYANE_PM10', 'HAUTE-NORMANDIE_PM10',
#        'ILE-DE-FRANCE_PM10', 'LA REUNION_PM10', 'LANGUEDOC-ROUSSILLON_PM10',
#        'LIMOUSIN_PM10', 'LORRAINE_PM10', 'MARTINIQUE_PM10',
#        'MIDI-PYRENEES_PM10', 'NORD-PAS-DE-CALAIS_PM10',
#        'PAYS DE LA LOIRE_PM10', 'PICARDIE_PM10', 'POITOU-CHARENTES_PM10',
#        'PROVENCE-ALPES-COTE D'AZUR_PM10', 'RHONE-ALPES_PM10',
#        'CHAMPAGNE-ARDENNE_O3', 'HAUTE-NORMANDIE_O3', 'ILE-DE-FRANCE_O3',
#        'LANGUEDOC-ROUSSILLON_O3', 'MIDI-PYRENEES_O3', 'NORD-PAS-DE-CALAIS_O3',
#        'RHONE-ALPES_O3', 'AQUITAINE_SO2', 'HAUTE-NORMANDIE_SO2',
#        'LA REUNION_SO2', 'NORD-PAS-DE-CALAIS_SO2', 'PAYS DE LA LOIRE_SO2',
#        'PROVENCE-ALPES-COTE D'AZUR_SO2', 'RHONE-ALPES_SO2'],
#       dtype='object')

# %%
allergies_regions = allergies_regions.loc['2016-10-01':'2017-06-01']
s = final_table.index
plt.figure(figsize=(10,3))
col_PACA = [col for col in final_table.columns if col.startswith("PROVENCE-ALPES-COTE D'AZUR")]
ax_pol = plt.subplot()
ax_pol.plot(s, allergies_regions["PROVENCE-ALPES-COTE D'AZUR"], color='#16a085')
ax_pol.set_ylabel('Niveau des pathologie allergènes', color='#16a085', fontsize=10)
ax_pol.tick_params('y', colors='#16a085')
plt.title("PROVENCE-ALPES-COTE D'AZUR", fontsize=14)
ax_reg = ax_pol.twinx()
ax_reg.plot(s, final_table[col_PACA], '^', color='#8e44ad')
ax_reg.set_ylabel('Dépassement de seuil d\'un polluant \n(microgr/m3)', color='#8e44ad', fontsize=10)
ax_reg.tick_params('y', colors='#8e44ad')
ax_reg.set_yticks([0, 50, 80, 180, 200, 300])
# Out:
# [<matplotlib.axis.YTick at 0x1104126a0>,
#  <matplotlib.axis.YTick at 0x110412b00>,
#  <matplotlib.axis.YTick at 0x11040b470>,
#  <matplotlib.axis.YTick at 0x111342c50>,
#  <matplotlib.axis.YTick at 0x111348630>,
#  <matplotlib.axis.YTick at 0x111348fd0>]

# %%
plt.figure(figsize=(20,15))
gs = gridspec.GridSpec(8, 3)
allergies_regions = allergies_regions.loc['2016-10-01':'2017-06-01']


n_pol = 0
for region in all_polluants_regions:
    
    col_pol_region = [col for col in final_table.columns if col.startswith(region)]
    s = final_table.index
    if (region in allergies_regions.columns):
        # Série temporelle des pathologies allergènes
        ax_pol = plt.subplot(gs[n_pol])
        ax_pol.plot(s, allergies_regions[region], color='#16a085')
        ax_pol.tick_params('y', colors='#16a085')
        plt.title(region, fontsize=14)
        ax_reg = ax_pol.twinx()
        ax_reg.plot(s, final_table[col_pol_region], '^', color='#8e44ad')
        ax_reg.tick_params('y', colors='#8e44ad')
        ax_reg.set_yticks([0, 50, 80, 180, 200, 300])
        n_pol += 1
        gs.update(hspace=0.7)
plt.show()

# %% [markdown]
# ## Zoom sur l'Île de France
#
# Données : airparif par polluant

# %%
# Monoxyde de carbone
CO = pd.read_csv('../data/20161001_20170601-CO_auto.csv', sep=';')
CO.head(2)
# Out:
#          date  heure         A1      PA04C        AUT      BASCH        AUB
# 0         NaN    NaN  microg/m3  microg/m3  microg/m3  microg/m3  microg/m3
# 1  01/10/2016    1.0        400        200        400        300        200

# %%
# Dioxyde d'azote
NO2 = pd.read_csv('../data/20161001_20170601-NO2_auto.csv', sep=';')
NO2.head(2)
# Out:
#          date  heure        ARG       EVRY        GEN     LOGNES      MELUN  \
# 0         NaN    NaN  microg/m3  microg/m3  microg/m3  microg/m3  microg/m3
# 1  01/10/2016    1.0         42         20         54         17          9
#
#       VILLEM      PA15L         A1    ...           ELYS      MONTG  \
# 0  microg/m3  microg/m3  microg/m3    ...      microg/m3  microg/m3
# 1         35        n/d         70    ...            n/d         21
#
#        NEUIL       PA12     BP_EST        AUB      EIFF3       IVRY  \
# 0  microg/m3  microg/m3  microg/m3  microg/m3  microg/m3  microg/m3
# 1         51         39         69         46         30         32
#
#         PA07      TREMB
# 0  microg/m3  microg/m3
# 1         39         28
#
# [2 rows x 43 columns]

# %%
# Poussières < 2.5
PM25 = pd.read_csv('../data/20161001_20170601-PM25_auto.csv', sep=';')
PM25.head(2)
# Out:
#          date  heure        GEN        GON         A1     RUR-SE        RN6  \
# 0         NaN    NaN  microg/m3  microg/m3  microg/m3  microg/m3  microg/m3
# 1  01/10/2016    1.0         11          7          7          5          4
#
#    RAMBO      RUR_S        BOB      PA04C      VITRY        AUT      RUR_N  \
# 0  ug/m3  microg/m3  microg/m3  microg/m3  microg/m3  microg/m3  microg/m3
# 1      8        n/d          7          9          7         14          5
#
#       BP_EST
# 0  microg/m3
# 1         11

# %%
# Poussières < 10
PM10 = pd.read_csv('../data/20161001_20170601-PM10_auto.csv', sep=';')
PM10.head(2)
# Out:
#          date  heure        GEN     LOGNES    AUT  PA15L      CERGY  \
# 0         NaN    NaN  microg/m3  microg/m3  ug/m3  ug/m3  microg/m3
# 1  01/10/2016    1.0         14         14     29    n/d         10
#
#       NOGENT         A1    RN2    ...          PA04C  RUR_S        RN6  \
# 0  microg/m3  microg/m3  ug/m3    ...      microg/m3  ug/m3  microg/m3
# 1         10         24     15    ...             16    n/d          8
#
#         HAUS      VITRY      RD934      BASCH       ELYS     BP_EST      TREMB
# 0  microg/m3  microg/m3  microg/m3  microg/m3  microg/m3  microg/m3  microg/m3
# 1         21         12          8         23         14         24         13
#
# [2 rows x 26 columns]

# %%
# Ozone
O3 = pd.read_csv('../data/20161001_20170601-O3_auto.csv', sep=';')
O3.head(2)
# Out:
#          date  heure     LOGNES      MELUN     VILLEM       CACH      CERGY  \
# 0         NaN    NaN  microg/m3  microg/m3  microg/m3  microg/m3  microg/m3
# 1  01/10/2016    1.0         19         25         11          7         20
#
#         PA13      RUR-E     RUR-NO    ...          PA04C     RUR-SO  \
# 0  microg/m3  microg/m3  microg/m3    ...      microg/m3  microg/m3
# 1         12         36         20    ...             13        n/d
#
#        VITRY      MONTG      NEUIL     RUR-NE      RAMBO      EIFF3  \
# 0  microg/m3  microg/m3  microg/m3  microg/m3  microg/m3  microg/m3
# 1        n/d          9        n/d         28         28         24
#
#        RUR_N      TREMB
# 0  microg/m3  microg/m3
# 1         12          8
#
# [2 rows x 27 columns]

# %%
# Dioxyde de souffre
SO2 = pd.read_csv('../data/20161001_20170601-SO2_auto.csv', sep=';')
SO2.head(2)
# Out:
#          date  heure     RUR-SE        AUT      VITRY      NEUIL        AUB  \
# 0         NaN    NaN  microg/m3  microg/m3  microg/m3  microg/m3  microg/m3
# 1  01/10/2016    1.0          1          0          1          0          0
#
#        EIFF3
# 0  microg/m3
# 1          0

# %%
# Oxyde d'azote
NOX = pd.read_csv('../data/20161001_20170601-NOX_auto.csv', sep=';')
len(NOX)
# Out:
# 5857

# %%
def clean_aggregate_polluant(df):
    df_clean = df.copy()
    # On enlève les unités de mesure 'microg/m3'
    df_clean = df_clean.iloc[1:]
    df_clean = df_clean.replace('n/d', np.nan)
    # Conversion de la date au bon format.
    df_clean.date = pd.to_datetime(df_clean.date, format='%d/%m/%Y')
    # Conversion en numérique
    for col in df_clean.columns[2:]:
        df_clean[col] = pd.to_numeric(df_clean[col])
    # Moyenne journalière.
    df_clean = df_clean.groupby('date')[df_clean.columns[2:]].mean()
    # Moyenne de toutes les stations.
    df_clean = df_clean.mean(axis=1)

    return df_clean.reset_index()

# %%
NOX = pd.read_csv('../data/20161001_20170601-NOX_auto.csv', sep=';')
NOX = clean_aggregate_polluant(NOX)
NOX.head(2)
# Out:
#         date          0
# 0 2016-10-01  72.061937
# 1 2016-10-02  60.377252

# %%
IDF_polluants = pd.DataFrame(pd.date_range('2016-10-01', '2017-06-01'), columns=['date'])
for pol in ['CO', 'NO2', 'PM25', 'PM10', 'O3', 'SO2', 'NOX']:
    polluant = pd.read_csv('../data/20161001_20170601-%s_auto.csv' % pol, sep=';')
    polluant_clean = clean_aggregate_polluant(polluant)
    polluant_clean.columns = ['date', pol]
    print('%s: %s lignes' % (pol, len(polluant_clean)))
    print('%s: OK' % pol)
    IDF_polluants = pd.merge(IDF_polluants, polluant_clean, on='date', how='left')
# Out:
# CO: 244 lignes
# CO: OK
# NO2: 244 lignes
# NO2: OK
# PM25: 244 lignes
# PM25: OK
# PM10: 244 lignes
# PM10: OK
# O3: 244 lignes
# O3: OK
# SO2: 244 lignes
# SO2: OK
# NOX: 244 lignes
# NOX: OK

# %%
IDF_polluants.set_index('date', inplace=True)

# %%
name_polluants = {
    'CO' : 'Dioxyde de carbone',
    'NO2': 'Dioxyde d\'azote',
    'PM25': 'Particules < 2.5um3',
    'PM10': 'Particules < 10um3',
    'O3': 'Ozone',
    'SO2': 'Dioxyde de souffre',
    'NOX': 'Oxyde d\'azote'
}

# %%
plt.figure(figsize=(20,15))
gs = gridspec.GridSpec(4, 2)
allergies_regions = allergies_regions.loc['2016-10-01':'2017-06-01']
s = allergies_regions.index


n_pol = 0
for pol in IDF_polluants.columns:
    if (n_pol == 0):    
        ax_pol = plt.subplot(gs[:1, :-1])
        n_pol += 1
    else:
        ax_pol = plt.subplot(gs[n_pol])
    ax_pol.plot(s, IDF_polluants[pol], color='#8e44ad')
    if (n_pol - 1 == 0):
        ax_pol.set_ylabel('Niveau du polluant\n(microgr/m3)', color='#8e44ad', fontsize=14)
    else:
        ax_pol.plot(s, IDF_polluants[pol], color='#8e44ad')
    ax_pol.tick_params('y', colors='#8e44ad')
    plt.title(name_polluants[pol], fontsize=14)
    
    ax_reg = ax_pol.twinx()
    ax_reg.plot(s, allergies_regions['ILE-DE-FRANCE'], '--', color='#16a085')
    if (n_pol - 1 == 0):
        ax_reg.set_ylabel('Niveau des pathologie allergènes', color='#16a085', fontsize=14)
    ax_reg.tick_params('y', colors='#16a085')
    n_pol += 1
plt.show()

# %% [markdown]
# Calculer la corrélation pour chaque polluant avec la série, puis plotter le polluant le plus corrélé avec le niveau de pathologie allergique.

# %%
IDF_polluants.corrwith(allergies_regions['ILE-DE-FRANCE'])
# Out:
# CO     -0.258490
# NO2    -0.217785
# PM25   -0.205211
# PM10   -0.146558
# O3      0.558341
# SO2    -0.158846
# NOX    -0.227293
# dtype: float64

# %%
IDF_polluants['O3'].corr(allergies_regions['ILE-DE-FRANCE'])
# Out:
# 0.55834055354239354

# %%
df = pd.concat([IDF_polluants['O3'], allergies_regions['ILE-DE-FRANCE']], axis=1)
df.head()
# Out:
#                    O3  ILE-DE-FRANCE
# 2016-10-01  39.990942         101.18
# 2016-10-02  42.411547         101.04
# 2016-10-03  31.141541         101.09
# 2016-10-04  40.219203         101.25
# 2016-10-05  41.320652         101.30

# %%
df.corr()
# Out:
#                      O3  ILE-DE-FRANCE
# O3             1.000000       0.558341
# ILE-DE-FRANCE  0.558341       1.000000

# %% [markdown]
# L'ozone et les pathologies allergique d'IDF sont très corélées (0.55) au jour-le-jour.
#
# Regardons ce qu'il se passe lorsque

# %% [markdown]
# ## Cross-correlation
#
# Regardons les corrélations entre O3(t-n) et les pathilogie allergènes en t. N = 1..10

# %%
fig = plt.figure(figsize=(15,5))
l_cross_corr = []
l_lags = range(1, 50)
for lag in l_lags:
    l_cross_corr.append(df['ILE-DE-FRANCE'].corr(df['O3'].shift(lag)))

plt.plot(l_lags, l_cross_corr, color='orange', label='Cross-corrélation')
plt.legend(loc='best')
plt.xlabel('Lag (jours)')
plt.title('Cross-corrélations entre le polluant Ozone (O3) et les pathologies allergiques en Île-de-France')

# %%
fig = plt.figure(figsize=(15,5))
ax1 = plt.subplot(211)
plt.title('Cross-correlation avec un lag de 38 jours \n(corrélation = 0.67)', fontsize=17)
df['O3'].shift(38).plot(ax=ax1, label='O3')
plt.legend(loc='upper left')
ax2 = plt.subplot(212)
df['ILE-DE-FRANCE'].plot(color='green', sharex=ax1, label='ILE-DE-FRANCE')
plt.legend(loc='upper left')

# %% [markdown]
# ## Rolling-correlation
#
# Regardons les corrélations entre mean(O3(t, t-w)) et les pathilogie allergènes en t. w = 1..30

# %%
fig = plt.figure(figsize=(15,5))

l_windows = range(2, 30)
l_rolling_corr = []
for w in l_windows:
    O3_mean_last_ndays = df['O3'].rolling(w).mean()
    l_rolling_corr.append(O3_mean_last_ndays.corr(df['ILE-DE-FRANCE']))

plt.plot(l_windows, l_rolling_corr, color='red', label='Rolling-correlation')
plt.legend(loc='best')
plt.xlabel('Fenêtre (jours)')
plt.title('Corrélations roulantes entre le polluant Ozone (O3) moyenné sur les N derniers jours et les pathologies allergiques en Île-de-France')

# %%
fig = plt.figure(figsize=(15,5))

df['O3_lean_last_30d'] = df['O3'].rolling(30).mean()
corr = df['O3_lean_last_30d'].corr(df['ILE-DE-FRANCE'])
ax1 = plt.subplot(211)
plt.title('Rolling-correlation avec une fenêtre de 30 jours\n(correlation = %.2f)' % corr, fontsize=17)
df['O3_lean_last_30d'].plot(ax=ax1, label='O3')
plt.legend(loc='upper left')
ax2 = plt.subplot(212)
df['ILE-DE-FRANCE'].plot(color='green', sharex=ax1, label='ILE-DE-FRANCE')
plt.legend(loc='upper left')

# %%
#pd.rolling_var(df, 5).plot(figsize=(20, 10))
f = plt.figure(figsize=(15, 12))

ax1 = plt.subplot(611)
plt.title('2-days window Rolling mean', fontsize=17)
df['O3'].rolling(2, min_periods=1).mean().plot(ax=ax1, label='O3')
plt.legend(loc='upper left')
ax2 = plt.subplot(612)
df['ILE-DE-FRANCE'].plot(color='green', sharex=ax1, label='ILE-DE-FRANCE')
plt.legend(loc='upper left')

ax3 = plt.subplot(613)
plt.title('10-days window Rolling mean', fontsize=17)
df['O3'].rolling(window=5, min_periods=5).mean().plot(ax=ax3)
ax4 = plt.subplot(614)
df['ILE-DE-FRANCE'].plot(color='green', sharex=ax3)


ax5 = plt.subplot(615)
plt.title('20-days window Rolling mean', fontsize=17)
df['O3'].rolling(window=20, min_periods=10).mean().plot(ax=ax5)
ax6 = plt.subplot(616)
df['ILE-DE-FRANCE'].plot(color='green', sharex=ax5)


plt.show()
